# %% [markdown]
# # Speed Dating
#
# # Description du défi
#
# ### Nous allons lancer un nouveau projet de visualisation et d'exploration des données. Votre objectif sera d'essayer de comprendre l'amour ! C'est un sujet très compliqué, nous l'avons donc simplifié. Votre objectif va être de comprendre ce qui se passe lors d'un speed dating et surtout de comprendre ce qui va influencer l'obtention d'un **second date**.
#
# ### Il s'agit d'une compétition Kaggle sur laquelle vous pouvez trouver plus de détails ici :
#
# [Speed Dating Dataset](https://www.kaggle.com/annavictoria/speed-dating-experiment#Speed%20Dating%20Data%20Key.doc)
#
# ### Prenez le temps de lire la description du défi et essayez de comprendre chacune des variables de l'ensemble de données. Aidez-vous pour cela du document : *Speed Dating - Variable Description.md*.
#
# # Rendu
#
# ### Pour réussir ce projet, vous devrez faire une analyse descriptive des principaux facteurs qui influencent l'obtention d'un second rendez-vous.
#
# ### Au cours des prochains jours, vous apprendrez à utiliser des bibliothèques python comme seaborn, plotly et bokeh pour produire des visualisations de données qui mettent en évidence des faits pertinents sur l'ensemble de données.
#
# ### Pour aujourd'hui, vous pouvez commencer à explorer l'ensemble de données avec pandas pour en extraire quelques statistiques.

# %%
# !pip install pandas==1.2.5
# !pip install pandas-profiling==2.8.0
# !pip install tqdm
# !pip install matplotlib==3.4

# %% [markdown]
# # Import Librairies

# %%
from pandas_profiling import ProfileReport

# %%
import pandas as pd
import numpy as np
import warnings
import warnings; warnings.filterwarnings(action='once')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
large = 18; med = 14; small = 11
params = {'axes.titlesize': large,
          'legend.fontsize': small,
          'figure.figsize': (16, 8),
          'axes.labelsize': small,
          'axes.titlesize': small,
          'xtick.labelsize': small,
          'ytick.labelsize': small,
          'figure.titlesize': med}
plt.rcParams.update(params)
plt.style.use('seaborn-whitegrid')
sns.set_style("white")
pd.set_option('display.max_columns', None)

# %%
#function to display values on bars or pies
def show_values_on_bars(axs):
  def _show_on_single_plot(ax):        
      for p in ax.patches:
          _x = p.get_x() + p.get_width() 
          _y = p.get_y() + p.get_height() / 2
          value = '{:.0f}'.format(p.get_width())
          ax.text(_x, _y, value, ha="center") 

  if isinstance(axs, np.ndarray):
      for idx, ax in np.ndenumerate(axs):
          _show_on_single_plot(ax)
  else:
      _show_on_single_plot(axs)

# %%
df2 = pd.read_csv('/home/jovyan/speed dating/Speed Dating Data.csv',sep=',',encoding='Windows-1252', engine='python')

# %% [markdown]
# # Unique people characteristics

# %%
# a person attend several rounds of meetings.
#we can just focus on its unique characteristics.
df = df2[['iid', 'wave',
        'gender', 'age', 'field', 'field_cd', 'undergra',
       'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
       'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
       'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
       'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
       'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
       'expnum','match_es',
       'match','dec',
       'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob',
       'met','satis_2', 'length', 'numdat_2',
       'you_call', 'them_cal', 'date_3', 'numdat_3',
       'num_in_3']].drop_duplicates(subset=['iid'])
df.describe()
# Out:
#               iid        wave      gender         age    field_cd        race  \
# count  551.000000  551.000000  551.000000  543.000000  544.000000  545.000000
# mean   276.787659   11.083485    0.502722   26.359116    7.549632    2.800000
# std    159.494486    6.013947    0.500447    3.766960    3.772699    1.253818
# min      1.000000    1.000000    0.000000   18.000000    1.000000    1.000000
# 25%    139.500000    6.000000    0.000000   24.000000    5.000000    2.000000
# 50%    277.000000   11.000000    1.000000   26.000000    8.000000    2.000000
# 75%    414.500000   15.000000    1.000000   28.000000   10.000000    4.000000
# max    552.000000   21.000000    1.000000   55.000000   18.000000    6.000000
#
#           imprace    imprelig        goal        date      go_out    career_c  \
# count  544.000000  544.000000  544.000000  543.000000  544.000000  539.000000
# mean     3.733456    3.582721    2.148897    4.983425    2.143382    5.250464
# ...

# %%
df.shape
# Out:
# (551, 59)

# %% [markdown]
# ## General exploration

# %%
report = ProfileReport(
    df,  html={"style": {"full_width": True}}, sort="None", minimal=True
)
report
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/widget/duplicate.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# /opt/conda/lib/python3.9/site-packages/pandas_profiling/report/presentation/flavours/widget/sample.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# /opt/conda/lib/python3.9/site-packages/pandas_profiling/profile_report.py:372: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
report.to_file("/home/jovyan/speed dating/report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Data processing

# %% [markdown]
# ### L'étape précédente a montré certaines caractéristiques avec une cardinalité (texte) extrêmement élevée.
#
# field : 259 distinct values
# undergra : 241 distinct values
# mn_sat : 68 distinct values
# tuition : 115 distinct values
# from : 269 distinct values
# zipcode : 409 distinct values
# career: 367 distinct values
#
# We will therefore remove these fields from the analysis
#
# champ : 259 valeurs distinctes
# undergra : 241 valeurs distinctes
# mn_sat : 68 valeurs distinctes
# tuition : 115 valeurs distinctes
# from : 269 valeurs distinctes
# zipcode : 409 valeurs distinctes
# profession : 367 valeurs distinctes
#
# Nous allons donc retirer ces champs de l'analyse

# %%
df = df[['iid', 
        'gender', 'age', 'field_cd', 
        'race', 'imprace', 'imprelig', 
       'income', 'goal', 'date', 'go_out', 
       'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
       'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
       'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',]]

# %% [markdown]
# # Cartographie du genre

# %%
df['gender'] = df['gender'].map({0:'women', 1:'men'})

# %%
ax=df.gender.value_counts(normalize=True).mul(100).plot(kind='barh')
plt.title('Les femmes moins que les hommes')

for c in ax.containers:
    ax.bar_label(c, label_type='center', color='yellow')

# %% [markdown]
# ### répartition de l'âge par sexe

# %%
plt.figure()

df[df.gender=='men'].age.plot(kind='kde', color='blue' ,alpha=0.3, label='Répartition par âge pour les hommes')
df[df.gender=='women'].age.plot(kind='kde', color='pink', label='Répartition par âge pour les femmes')
plt.legend()
plt.show()

# %% [markdown]
# #### Répartition similaire des âges entre hommes et femmes

# %% [markdown]
# ### Voyons la répartition par tranche d'âge :

# %%
# Résumer les âges à travers un ensemble de données spécifiques.

df['age'] = df.age.fillna(int(df.age.mean()))
df['age_c'] = ['<20' if x <20 else '<25' if x <25  else '<30' if x <30   else '>30' for x in df['age']]
dataset = df.groupby(by='age_c')['gender'].value_counts(normalize=True).mul(100).to_frame().rename(columns={'gender' : 'count'}).reset_index('gender')

# Pour obtenir un bon graphique de pyramide des âges, nous devons annuler les valeurs d'une des variables catégorielles.
# Dans ce cas, les femmes.

def minus(x,y):
  if y == 'women':
    x = -1 * x
  return round(x,0)

dataset['count'] = dataset.apply(lambda x: minus(x['count'], x['gender']), axis=1)
dataset
# Out:
#       gender  count
# age_c
# <20      men   67.0
# <20    women  -33.0
# <25    women  -56.0
# <25      men   44.0
# <30      men   53.0
# <30    women  -47.0
# >30      men   54.0
# >30    women  -46.0

# %% [markdown]
# ### Nous pouvons maintenant dessiner notre diagramme pyramidal pour mettre en valeur la différence d'âge entre les hommes et les femmes

# %%
fig, ax = plt.subplots(figsize=(16,8))

m = dataset[dataset.gender == 'men']['count'].sort_index().plot(kind='barh', label = 'répartition par âge en % pour les hommes')

for c in ax.containers:
    ax.bar_label(c, label_type='center',color='white')
w = dataset[dataset.gender == 'women']['count'].sort_index().plot(kind='barh', color='pink', label = 'répartition par âge en % pour les femmes')
for c in ax.containers:
    ax.bar_label(c, label_type='center')
plt.title('Plus de femmes jeunes que d hommes en %', fontsize = 20)
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Cartographie de l'origine

# %%
df['race'] = df['race'].fillna(0) #6 people
df['race'] = ['Black' if x == 1 else 'European' if x ==2  else 'Latino' if x == 3 else 'Asian' if x == 4 else 'Native' if x == 5 else 'Other' for x in df['race']]

# %%
import warnings
warnings.filterwarnings("ignore")

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
df[df.gender =='women'].race.value_counts().plot(kind='pie')
plt.title('Répartition origine des femmes', fontsize = 20)
centre_circle = plt.Circle((0,0),0.65,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.subplot(1,2,2)
df[df.gender =='men'].race.value_counts().plot(kind='pie',)
plt.title('Répartition origine des hommes', fontsize = 20)
centre_circle = plt.Circle((0,0),0.65,fc='white')

fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %% [markdown]
# #### Les Européens et les Asiatiques sont surreprésentés chez les hommes et les femmes.
# #### avec probablement des hommes plus âgés.
# #### Un peu plus de filles asiatiques que de garçons ; un peu plus de garçons européens que de filles.

# %% [markdown]
# ## Voyons la répartition des races par âge

# %%
ax = df[df.gender=='women'].groupby(by=[ 'age_c','race'])['race'].agg(['count']).rename(columns={'count' : '#people'}).sort_index(axis = 0).unstack().fillna(0).plot(kind='barh', stacked=True, label = 'race_repartition by age range');
for c in ax.containers:
    ax.bar_label(c, label_type='center', color='white')
plt.legend(loc = 'best')
plt.show()

# %%
#Age repartition by race & gender

ax1 = df[df.gender=='women'].groupby(by=['race', 'age_c'])['age_c'].agg(['count']).rename(columns={'count' : '#people'}).sort_index(axis = 0).unstack().fillna(0).plot(stacked=True, kind= 'barh')
for c in ax1.containers:
    ax1.bar_label(c, label_type='center', color='white')
plt.legend(loc = 'best')
plt.title('répartition des femmes par âge et par race', fontsize = 20);


ax2 = df[df.gender=='men'].groupby(by=['race', 'age_c'])['age_c'].agg(['count']).rename(columns={'count' : '#people'}).sort_index(axis = 0).unstack().fillna(0).plot(stacked=True, kind= 'barh')
for c in ax2.containers:
    ax2.bar_label(c, label_type='center', color='white')
plt.legend(loc = 'best')
plt.title('répartition des hommes par âge et par race',fontsize = 20);

# %% [markdown]
# #### Les Européens et les Asiatiques sont les plus fréquemment rencontrés.
# #### C'est parmi les hommes européens que l'on trouve le plus de personnes de plus de 25 ans, quel que soit leur sexe.

# %% [markdown]
# # Traçons la répartition des races par tranche d'âge.

# %%
ax1 = df[df.gender=='women'].groupby(by=[ 'age_c','race'])['race'].agg(['count']).rename(columns={'count' : '#people'}).sort_index(axis = 0).unstack().fillna(0).plot(kind='barh', stacked=True)
for c in ax1.containers:
    ax1.bar_label(c, label_type='center', color='white')
plt.legend(loc = 'best')
plt.title('Répartition des races par âge chez les femmes', fontsize = 20);


ax2 = df[df.gender=='men'].groupby(by=[ 'age_c','race'])['race'].agg(['count']).rename(columns={'count' : '#people'}).sort_index(axis = 0).unstack().fillna(0).plot(kind='barh', stacked=True)
for c in ax2.containers:
    ax2.bar_label(c, label_type='center', color='white')
plt.legend(loc = 'best')
plt.title('Répartition des races par âge chez les hommes', fontsize = 20);

# %% [markdown]
# # Existe-t-il des disparités importantes entre les hommes et les femmes en termes d'éducation ?

# %%
df['field_cd'].fillna(0, inplace=True)

education = { 
              0 : 'unknown',
              1 : 'Law ',
              2 : 'Math',
              3 : 'Social Science',
              4 : 'Medical Science',
              5 : 'Engineering  ',
              6 : 'Litterature',
              7 : 'History',
              8 : 'Business',
              9 : 'Education',
              10 : 'Sciences',
              11 : 'Social Work ',
              12 : 'Undergrad',
              13: 'Political Affairs ',
              14 : 'Film',
              15 : 'Fine Arts',
              16: 'Languages',
              17 : 'Architecture',
              18 : 'Other'}

df['field_cd'] = df.field_cd.map(education)

# %%
temp = df.groupby(by=['field_cd', 'gender'])['gender'].agg('count').unstack().fillna(0)
temp.women = temp.apply(lambda x: -1 * x['women'], axis=1)

fig = plt.figure()
ax = temp.sort_values(by='men', ascending=True).plot(kind='barh',stacked=True, figsize=(34,30))
for c in ax.containers:
    ax.bar_label(c, label_type='center', color = 'white' )
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Une surreprésentation des hommes dans les domaines du commerce et de l ingénierie;
# ### Une surreprésentation des femmes dans les domaines des sciences sociales, de la littérature et de l éducation

# %% [markdown]
# # Un niveau de vie élevé entraîne-t-il plus de rendez-vous ?

# %%
data = pd.read_csv('/home/jovyan/speed dating/Speed Dating Data.csv',sep=',',encoding='Windows-1252', engine='python')
data.dropna(subset=['income']).drop_duplicates(subset=['iid'])
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 10      2   2.0       0    3       1     1     10         3       NaN     10
# 30      4   4.0       0    7       1     1     10         6       NaN      3
# 40      5   5.0       0    9       1     1     10         4       NaN      1
# 50      6   6.0       0   11       1     1     10         8       NaN      5
# ...   ...   ...     ...  ...     ...   ...    ...       ...       ...    ...
# 8026  537   7.0       1   14       2    21     22        21      13.0      9
# 8158  543  13.0       1   26       2    21     22        21      12.0     10
# 8180  544  14.0       1   28       2    21     22        21       5.0     17
# 8202  545  15.0       1   30       2    21     22        21      19.0      3
# 8334  551  21.0       1   42       2    21     22        21      21.0      1
#
# ...

# %%
# Regardons les enregistrements manquants du revenu
data.income.isna().sum()/len(data.income) * 100
# Out:
# 48.92575793745524

# %% [markdown]
#  50% des données de revenus sont manquantes !

# %%
# Supprimons les 
data_revenue = data.dropna(subset=['income'])

# %%
data_revenue = data_revenue[['gender', 'age', 'race',  'imprace', 'imprelig', 
       'income', 'goal', 'date', 'go_out', 'career', 'career_c', 'sports',
       'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking', 'gaming',
       'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts', 'music',
       'shopping', 'yoga', 'exphappy', 'expnum', 'match_es', 'match', 'dec',
       'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob', 'met',
       'satis_2', 'length', 'numdat_2', 'you_call', 'them_cal', 'date_3',
       'numdat_3', 'num_in_3']][(data.wave == 1)]

# %%
# We need to clean the income records
def _int(x):
  if x!=0:
    x = str(x)
    x = int(x[0:x.find('.')].replace(',',''))
  return x

data_revenue['income'] = data_revenue.apply(lambda x: _int(x['income']), axis=1)
sns.pairplot(data_revenue[['age', 'gender','race', 'imprace', 'imprelig', 
       'income', 'match']], hue='gender',corner=True,kind="kde");

# %% [markdown]
# # La seule corrélation claire que nous pouvons discerner est que les filles qui accordent beaucoup d'importance à la religion accordent beaucoup d'importance à la race de leur partenaire.

# %% [markdown]
# # D'autres corrélations ?

# %%
# !pip install phik

# %%
small = df2[[ 'gender', 'age', 'field_cd',  'race', 'imprace', 'imprelig',  'goal', 'date', 'go_out', 'career_c', 'match']]

# %%
check = small.corr() 
check[abs(check) > 0.3].fillna('')
# Out:
#          gender  age  field_cd race   imprace  imprelig goal      date  \
# gender      1.0
# age              1.0
# field_cd                   1.0
# race                            1.0
# imprace                                   1.0  0.430284
# imprelig                             0.430284       1.0
# goal                                                     1.0
# date                                                               1.0
# go_out                                                        0.336955
# career_c              0.353927
# match
#
#             go_out  career_c match
# gender
# age
# field_cd            0.353927
# race
# imprace
# imprelig
# goal
# date      0.336955
# go_out         1.0
# career_c                 1.0
# match                          1.0

# %%
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(small.corr(), xticklabels=small.corr().columns, yticklabels=small.corr().columns, cmap='RdYlGn', center=0, annot=True, )

# Decorations
plt.title('Correlogram of personal attributes', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12,rotation=0.3)
plt.show()

# %% [markdown]
# ### corrélation entre carer_c et field_cd:  le fait que le type d'étude influence la carrière.
# ###  corrélation entre race et imprelig:  'il y a un lien entre la race et la religion.
# ### Mais aucun attribut n'est corrélé avec un deuxième rendez-vous.

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
